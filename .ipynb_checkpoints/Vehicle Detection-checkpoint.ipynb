# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
from plot3d import plot3d

# %%
# Read a color image
#img = cv2.imread("000275.png")

img = cv2.imread("test_images/test1.jpg")

# Select a small fraction of pixels to plot by subsampling it
scale = max(img.shape[0], img.shape[1], 64) / 64  # at most 64 rows and columns
img_small = cv2.resize(img, (np.int(img.shape[1] / scale), np.int(img.shape[0] / scale)), interpolation=cv2.INTER_NEAREST)

# Convert subsampled image to desired color space(s)
img_small_RGB = cv2.cvtColor(img_small, cv2.COLOR_BGR2RGB)  # OpenCV uses BGR, matplotlib likes RGB
img_small_HSV = cv2.cvtColor(img_small, cv2.COLOR_BGR2HSV)
img_small_rgb = img_small_RGB / 255.  # scaled to [0, 1], only for plotting

plt.imshow(img_small_RGB)

# Plot and show
plot3d(img_small_RGB, img_small_rgb)
plt.show()

plot3d(img_small_HSV, img_small_rgb, axis_labels=list("HSV"))
plt.show()

# %%
# Read a color image
img = cv2.imread("25.png")

img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rgb = img_RGB / 255.  # scaled to [0, 1], only for plotting

img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_HLS = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
img_LUV = cv2.cvtColor(img, cv2.COLOR_BGR2LUV)

plt.imshow(img_RGB)

# Plot and show
plot3d(img_RGB, img_rgb)
plt.show()

plot3d(img_HSV, img_rgb, axis_labels=list("HSV"))
plt.show()

plot3d(img_HLS, img_rgb, axis_labels=list("HLS"))
plt.show()

plot3d(img_LUV, img_rgb, axis_labels=list("LUV"))
plt.show()

# %%
# Read a color image
img = cv2.imread("31.png")

img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rgb = img_RGB / 255.  # scaled to [0, 1], only for plotting

img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_HLS = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
img_LUV = cv2.cvtColor(img, cv2.COLOR_BGR2LUV)

plt.imshow(img_RGB)

# Plot and show
plot3d(img_RGB, img_rgb)
plt.show()

plot3d(img_HSV, img_rgb, axis_labels=list("HSV"))
plt.show()

plot3d(img_HLS, img_rgb, axis_labels=list("HLS"))
plt.show()

plot3d(img_LUV, img_rgb, axis_labels=list("LUV"))
plt.show()

# %%
# Read a color image
img = cv2.imread("53.png")

img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rgb = img_RGB / 255.  # scaled to [0, 1], only for plotting

img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_HLS = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
img_LUV = cv2.cvtColor(img, cv2.COLOR_BGR2LUV)

plt.imshow(img_RGB)

# Plot and show
plot3d(img_RGB, img_rgb)
plt.show()

plot3d(img_HSV, img_rgb, axis_labels=list("HSV"))
plt.show()

plot3d(img_HLS, img_rgb, axis_labels=list("HLS"))
plt.show()

plot3d(img_LUV, img_rgb, axis_labels=list("LUV"))
plt.show()

# %%
# Read a color image
img = cv2.imread("8.png")

img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rgb = img_RGB / 255.  # scaled to [0, 1], only for plotting

img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_HLS = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
img_LUV = cv2.cvtColor(img, cv2.COLOR_BGR2LUV)

plt.imshow(img_RGB)

# Plot and show
plot3d(img_RGB, img_rgb)
plt.show()

plot3d(img_HSV, img_rgb, axis_labels=list("HSV"))
plt.show()

plot3d(img_HLS, img_rgb, axis_labels=list("HLS"))
plt.show()

plot3d(img_LUV, img_rgb, axis_labels=list("LUV"))
plt.show()

# %%
# Read a color image
img = cv2.imread("data/vehicles/GTI_Far/image0000.png")

img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rgb = img_RGB / 255.  # scaled to [0, 1], only for plotting

img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_HLS = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
img_LUV = cv2.cvtColor(img, cv2.COLOR_BGR2LUV)

plt.imshow(img_RGB)

# Plot and show
plot3d(img_RGB, img_rgb)
plt.show()

plot3d(img_HSV, img_rgb, axis_labels=list("HSV"))
plt.show()

plot3d(img_HLS, img_rgb, axis_labels=list("HLS"))
plt.show()

plot3d(img_LUV, img_rgb, axis_labels=list("LUV"))
plt.show()

# %%
# Read a color image
img = cv2.imread("test_images/test2.jpg")

img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rgb = img_RGB / 255.  # scaled to [0, 1], only for plotting

img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_HLS = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
img_LUV = cv2.cvtColor(img, cv2.COLOR_BGR2LUV)

plt.imshow(img_RGB)

# Plot and show
#plot3d(img_RGB, img_rgb)
#plt.show()

#plot3d(img_HSV, img_rgb, axis_labels=list("HSV"))
#plt.show()

#plot3d(img_HLS, img_rgb, axis_labels=list("HLS"))
#plt.show()

plot3d(img_LUV, img_rgb, axis_labels=list("LUV"))
plt.show()

# %%
from search_classify import *

svc, X_scaler = train_classifier(color_space='LUV', hog_channel='ALL')
# Out:
# /home/yipstar/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Using: 9 orientations 8 pixels per cell and 2 cells per block
# Feature vector length: 8460
# 21.89 Seconds to train SVC...
# Test Accuracy of SVC =  0.9961

# %%
# image = mpimg.imread('bbox-example-image.jpg')
image = cv2.imread('test_images/test1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# y_start_stop = [None, None] # Min and max in y to search in slide_window()
y_start_stop = [350, 700]

windowed_img = tracking_pipeline(image, svc, X_scaler, y_start_stop=y_start_stop, color_space='LUV', hog_channel='ALL')
plt.imshow(windowed_img)
# Out:
# total windows size 318

# %%
# image = mpimg.imread('bbox-example-image.jpg')
image = cv2.imread('test_images/test1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# y_start_stop = [None, None] # Min and max in y to search in slide_window()
y_start_stop = [350, 700]

heatmap = tracking_pipeline(image, svc, X_scaler, y_start_stop=y_start_stop, color_space='LUV', hog_channel='ALL')
plt.imshow(heatmap, cmap='hot')
# Out:
# total windows size 318

# %%
# image = mpimg.imread('bbox-example-image.jpg')
image = cv2.imread('test_images/test1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# y_start_stop = [None, None] # Min and max in y to search in slide_window()
y_start_stop = [350, 700]

stage = 'final'

windowed_img = tracking_pipeline(image, svc, X_scaler, y_start_stop=y_start_stop, color_space='LUV', hog_channel='ALL', stage=stage)
plt.imshow(windowed_img)
# Out:
# total windows size 647

# %%
image = cv2.imread('bbox-example-image.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# y_start_stop = [None, None] # Min and max in y to search in slide_window()
y_start_stop = [350, 700]

windowed_img = tracking_pipeline(image, svc, X_scaler, y_start_stop=y_start_stop, color_space='LUV', hog_channel='ALL')
plt.imshow(windowed_img)
# Out:
# total windows size 634

# %%
def show_2_images(img1, img1_label, img2, img2_label, cmap = None):
    # Visualize undistortion
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

    ax1.imshow(img1, cmap=cmap)
    ax1.set_title(img1_label, fontsize=30)

    ax2.imshow(img2, cmap=cmap)
    ax2.set_title(img2_label, fontsize=30)

# %%
img = mpimg.imread(cars[0])
img2 = mpimg.imread(notcars[0])

show_2_images(img, 'car', img2, 'notcar')

# %%
print(len(cars))
print(len(notcars))

car_i = np.random.randint(0, len(cars))
notcar_i = np.random.randint(0, len(notcars))

img = mpimg.imread(cars[car_i])
img2 = mpimg.imread(notcars[notcar_i])

show_2_images(img, 'car', img2, 'notcar')

# %%
image = cv2.imread('test_images/test3.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# y_start_stop = [None, None] # Min and max in y to search in slide_window()
y_start_stop = [350, 700]

windowed_img = tracking_pipeline(image, svc, X_scaler, y_start_stop=y_start_stop, color_space='LUV', hog_channel='ALL')
plt.imshow(windowed_img)
# Out:
# total windows size 318

# %%
image = cv2.imread('test_images/test6.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# y_start_stop = [None, None] # Min and max in y to search in slide_window()
y_start_stop = [350, 700]

stage='hot'
#stage='heat'
stage='final'

windowed_img = tracking_pipeline(image, svc, X_scaler, color_space='LUV', hog_channel='ALL', stage=stage)
plt.imshow(windowed_img)
# Out:
# total windows size 587

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
def pipeline_with_params(img):
    return tracking_pipeline(img, svc, X_scaler, color_space='LUV', hog_channel='ALL')

# %%
video_output = 'test_video_output.mp4'
clip1 = VideoFileClip("test_video.mp4")

# NOTE: this function expects color images!!
output_clip = clip1.fl_image(pipeline_with_params)

# %time output_clip.write_videofile(video_output, audio=False)
# Out:
# [MoviePy] >>>> Building video test_video_output.mp4
# [MoviePy] Writing video test_video_output.mp4
#  97%|█████████▋| 38/39 [01:47<00:02,  2.85s/it]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_video_output.mp4
#
# CPU times: user 8min 50s, sys: 9.58 s, total: 9min
# Wall time: 1min 48s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(video_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_video_output.mp4">
# </video>

# %%
video_output2 = 'project_video_output.mp4'
clip1 = VideoFileClip("project_video.mp4")

# NOTE: this function expects color images!!
output_clip = clip1.fl_image(pipeline_with_params)

# %time output_clip.write_videofile(video_output2, audio=False)
# Out:
# [MoviePy] >>>> Building video project_video_output.mp4
# [MoviePy] Writing video project_video_output.mp4
# 100%|█████████▉| 1260/1261 [59:21<00:02,  2.83s/it]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: project_video_output.mp4
#
# CPU times: user 4h 51min 27s, sys: 5min 19s, total: 4h 56min 47s
# Wall time: 59min 21s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(video_output2))
# Out:
# <video width="960" height="540" controls>
#   <source src="project_video_output.mp4">
# </video>

# %%
# TODO: try color space 'YCrCb'
